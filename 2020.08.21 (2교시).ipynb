# %% [markdown]
# # lazy evaluation

# %%
import pickle

# %%
with open('C:/Users/Playdata/Downloads/20200821/20200821/kbo_1700.pkl', 'rb') as f:
    kbo_list = pickle.load(f)

# %%
kbo_list
# Out:
# ['61295',
#  '79358',
#  '62925',
#  '50905',
#  '65933',
#  '67991',
#  '63963',
#  '60339',
#  '65462',
#  '67900',
#  '69980',
#  '62934',
#  '68900',
#  '67989',
#  '63920',
#  '66943',
#  '75867',
#  '67954',
#  '66917',
#  '68906',
#  '50992',
#  '78122',
#  '64984',
#  '67956',
#  '50902',
#  '68912',
#  '67901',
#  '62947',
#  '50955',
#  '69996',
#  '62931',
#  '50990',
#  '50912',
#  '69940',
#  '65949',
#  '78813',
#  '65901',
#  '66996',
#  '64944',
#  '62907',
#  '74465',
#  '65206',
#  '50996',
#  '50906',
#  '66928',
#  '69994',
#  '63991',
#  '69974',
#  '64995',
#  '69995',
#  '67962',
#  '63914',
#  '65909',
#  '69962',
#  '68902',
#  '67944',
#  '50901',
#  '50923',
#  '76232',
#  '68904',
#  '76118',
#  '63903',
#  '62537',
#  '76849',
#  '62929',
#  '60566',
#  '68910',
#  '62025',
#  '67993',
#  '60263',
#  '50904',
#  '65937',
#  '66990',
#  '63959',
#  '78352',
#  '50900',
#  '63950',
#  '69969',
#  '50995',
#  '76720',
#  '73306',
#  '66920',
#  '65905',
# ...

# %%
len(kbo_list)
# Out:
# 843

# %%
for id_ in kbo_list:
    print('https://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId={}'.format(id_))
    break
# Out:
# https://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=61295

# %%
import requests

# %%
r = requests.get('https://www.koreabaseball.com/Record/Player/HitterDetail/Basic.aspx?playerId=61295')

# %%
r.text
# Out:
# '\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<head><title>\r\n\t선수(타자) | 기록실 | KBO\r\n</title><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta http-equiv="Content-Script-Type" content="text/javascript" /><meta http-equiv="Content-Style-Type" content="text/css" /><meta http-equiv="X-UA-Compatible" content="IE=edge, Chrome" /><meta name="title" content="KBO" /><meta name="author" content="스포츠투아이" /><meta name="keywords" content="KBO, 한국야구위원회, 프로야구, KBO 리그, 퓨처스리그, 프로야구순위, 프로야구 일정" /><meta name="viewport" content="width=1200" /><meta property="og:type" content="website" /><meta property="og:title" content="KBO 홈페이지" /><meta property="og:description" content="KBO, 한국야구위원회, 프로야구, KBO 리그, 퓨처스리그, 프로야구순위, 프로야구 일정" /><meta property="og:image" content="//lgcxydabfbch3774324.cdn.ntruss.com/KBO_IMAGE/KBOHome/resources/images/common/open_graph_kbo.png" /><meta property="og:url" content="//www.koreabaseball.com/" />\r\n\r\n\t<link rel="shortcut icon" type="image/x-icon"
# ...

# %%
from bs4 import BeautifulSoup as BS

# %%
bs = BS(r .text)

# %%
bs
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head><title>
# 	선수(타자) | 기록실 | KBO
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="text/javascript" http-equiv="Content-Script-Type"/><meta content="text/css" http-equiv="Content-Style-Type"/><meta content="IE=edge, Chrome" http-equiv="X-UA-Compatible"/><meta content="KBO" name="title"/><meta content="스포츠투아이" name="author"/><meta content="KBO, 한국야구위원회, 프로야구, KBO 리그, 퓨처스리그, 프로야구순위, 프로야구 일정" name="keywords"/><meta content="width=1200" name="viewport"/><meta content="website" property="og:type"/><meta content="KBO 홈페이지" property="og:title"/><meta content="KBO, 한국야구위원회, 프로야구, KBO 리그, 퓨처스리그, 프로야구순위, 프로야구 일정" property="og:description"/><meta content="//lgcxydabfbch3774324.cdn.ntruss.com/KBO_IMAGE/KBOHome/resources/images/common/open_graph_kbo.png" property="og:image"/><meta content="//www.koreabaseball.com/" property="og:url"/>
# ...

# %%
bs.find('span', id = "cphContents_cphContents_cphContents_playerProfile_lblName")
# Out:
# <span id="cphContents_cphContents_cphContents_playerProfile_lblName">강동연</span>

# %%
bs.find('span', id = "cphContents_cphContents_cphContents_playerProfile_lblName").text
# Out:
# '강동연'

# %%
bs.find('span', id="cphContents_cphContents_cphContents_playerProfile_lblBackNo").text
# Out:
# '21'

# %%
bs.find_all('li', class_='odd')
# Out:
# [<li class="odd"><strong>선수명: </strong><span id="cphContents_cphContents_cphContents_playerProfile_lblName">강동연</span></li>,
#  <li class="odd"><strong>생년월일: </strong><span id="cphContents_cphContents_cphContents_playerProfile_lblBirthday">1992년 12월 18일</span></li>,
#  <li class="odd"><strong>신장/체중: </strong><span id="cphContents_cphContents_cphContents_playerProfile_lblHeightWeight">195cm/94kg</span></li>,
#  <li class="odd"><strong>입단 계약금: </strong><span id="cphContents_cphContents_cphContents_playerProfile_lblPayment"></span></li>,
#  <li class="odd"><strong>지명순위: </strong><span id="cphContents_cphContents_cphContents_playerProfile_lblDraft">11 두산 육성선수</span></li>]

# %%
왼쪽_리스트 = []
오른쪽_리스트 = []

for x in bs.find_all('li', class_='odd'):
    왼쪽, 오른쪽 = x.text.split(':')

# %%
pd.DataFrame(dict(zip(왼쪽_리스트, 오른쪽_리스트)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-d3d93f353c7e> in <module>
# ----> 1 pd.DataFrame(dict(zip(왼쪽_리스트, 오른쪽_리스트)))
#
# NameError: name 'pd' is not defined
