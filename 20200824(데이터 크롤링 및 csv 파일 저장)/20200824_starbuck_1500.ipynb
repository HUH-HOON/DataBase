# %%
import requests
import json

# %%
url = "https://www.starbucks.co.kr/store/getStore.do?"

# %%
payload = {'in_biz_cds': '0',
'in_scodes': '0',
'ins_lat': '37.490628099999995',
'ins_lng': '127.0106409',
'search_text': '',
'p_sido_cd': '01',
'p_gugun_cd': '',
'in_distance': '0',
'in_biz_cd': '',
'isError': 'true',
'searchType': 'C',
'set_date': '',
'all_store': '0',
'T03': '0',
'T01': '0',
'T12': '0',
'T09': '0',
'T30': '0',
'T05': '0',
'T22': '0',
'T21': '0',
'T10': '0',
'T36': '0',
'P10': '0',
'P50': '0',
'P20': '0',
'P60': '0',
'P30': '0',
'P70': '0',
'P40': '0',
'P80': '0',
'whcroad_yn': '0',
'P90': '0',
'new_bool': '0',
'iend': '1000',
'rndCod': '4908HSPNL6',}

# %% [markdown]
# for code in ['01', '08']:
#     payload['p_sido_cd'] = code

# %% [markdown]
# payload = {
#     'in_biz_cds': '0',
#     'in_scodes': '0',
#     'ins_lat': '37.490628099999995',
#     'ins_lng': '127.0106409',
#     'search_text': '',
#     'p_sido_cd': '01',
#     'p_gugun_cd': '',
#     'in_distance': '0',
#     'in_biz_cd': '',
#     'isError': 'true',
#     'searchType': 'C',
#     'set_date': '',
#     'all_store': '0',
#     'T03': '0',
#     'T01': '0',
#     'T12': '0',
#     'T09': '0',
#     'T30': '0',
#     'T05': '0',
#     'T22': '0',
#     'T21': '0',
#     'T10': '0',
#     'T36': '0',
#     'P10': '0',
#     'P50': '0',
#     'P20': '0',
#     'P60': '0',
#     'P30': '0',
#     'P70': '0',
#     'P40': '0',
#     'P80': '0',
#     'whcroad_yn': '0',
#     'P90': '0',
#     'new_bool': '0',
#     'iend': '1000',
#     'rndCod': '4908HSPNL6',
# }

# %%
header= {
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'Connection': 'keep-alive',
    'Content-Length': '348',
    'Host': 'www.starbucks.co.kr',
    'Origin': 'https://www.starbucks.co.kr',
    'Referer': 'https://www.starbucks.co.kr/store/store_map.do?disp=locale',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest',
}

# %%
url = 'https://www.starbucks.co.kr/store/getStore.do?'
r = requests.post(url, data= payload, headers=header)

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '{"list":[{"seq":0,"sido_cd":null,"sido_nm":null,"gugun_cd":null,"gugun_nm":null,"code_order":null,"view_yn":null,"store_num":null,"sido":null,"gugun":null,"address":null,"new_img_nm":null,"p_pro_seq":0,"p_view_yn":null,"p_sido_cd":"","p_gugun_cd":"","p_store_nm":null,"p_theme_cd":null,"p_wireless_yn":null,"p_smoking_yn":null,"p_book_yn":null,"p_music_yn":null,"p_terrace_yn":null,"p_table_yn":null,"p_takeout_yn":null,"p_parking_yn":null,"p_dollar_assent":null,"p_card_recharge":null,"p_subway_yn":null,"stb_store_file_renew":null,"stb_store_theme_renew":null,"stb_store_time_renew":null,"stb_store_lsm":null,"s_code":"1596","s_name":"소노캄고양","tel":"1522-3232","fax":"031-921-3841","sido_code":"08","sido_name":"경기","gugun_code":"0802","gugun_name":"고양시 일산동구","addr":"경기도 고양시 일산동구 장항동 1755 ","park_info":null,"new_state":null,"theme_state":"T04@T05@T08@T16@T17@T20@T21@T30@T34","new_bool":0,"search_text":"","ins_lat":"","ins_lng":"","in_distance":0,"out_distance":"29.78","all_search_cnt":-1,"ad
# ...

# %%
rt = json.loads(r.text)

# %%
star
# Out:
# {'seq': 0,
#  'sido_cd': None,
#  'sido_nm': None,
#  'gugun_cd': None,
#  'gugun_nm': None,
#  'code_order': None,
#  'view_yn': None,
#  'store_num': None,
#  'sido': None,
#  'gugun': None,
#  'address': None,
#  'new_img_nm': None,
#  'p_pro_seq': 0,
#  'p_view_yn': None,
#  'p_sido_cd': '',
#  'p_gugun_cd': '',
#  'p_store_nm': None,
#  'p_theme_cd': None,
#  'p_wireless_yn': None,
#  'p_smoking_yn': None,
#  'p_book_yn': None,
#  'p_music_yn': None,
#  'p_terrace_yn': None,
#  'p_table_yn': None,
#  'p_takeout_yn': None,
#  'p_parking_yn': None,
#  'p_dollar_assent': None,
#  'p_card_recharge': None,
#  'p_subway_yn': None,
#  'stb_store_file_renew': None,
#  'stb_store_theme_renew': None,
#  'stb_store_time_renew': None,
#  'stb_store_lsm': None,
#  's_code': '1668',
#  's_name': '묵동',
#  'tel': '1522-3232',
#  'fax': '02-971-3937',
#  'sido_code': '01',
#  'sido_name': '서울',
#  'gugun_code': '0125',
#  'gugun_name': '중랑구',
#  'addr': '서울특별시 중랑구 묵동 169-12 1층',
# ...

# %%
import pandas as pd

# %% [markdown]
# pd.DataFrame([ (key, value) for key, value in star.items()])

# %%
for star in rt['list']:
    print( "매장 이름 : {}".format(star['s_name']))
    print( "주소      : {}".format(star['addr']))
# Out:
# 매장 이름 : 역삼아레나빌딩
# 주소      : 서울특별시 강남구 역삼동 721-13 아레나빌딩
# 매장 이름 : 논현역사거리
# 주소      : 서울특별시 강남구 논현동 142-2 정일빌딩
# 매장 이름 : 신사역성일빌딩
# 주소      : 서울특별시 강남구 논현동 18-4 성일빌딩
# 매장 이름 : 국기원사거리
# 주소      : 서울특별시 강남구 역삼동 648-22 동찬빌딩
# 매장 이름 : 스탈릿대치R
# 주소      : 서울특별시 강남구 대치동 599 대원빌딩
# 매장 이름 : 봉은사역
# 주소      : 서울특별시 강남구 삼성동 108-6 JBK TOWER 빌딩
# 매장 이름 : 압구정윤성빌딩
# 주소      : 서울특별시 강남구 신사동 592 윤성빌딩
# 매장 이름 : 코엑스별마당
# 주소      : 서울특별시 강남구 삼성동 159 코엑스
# 매장 이름 : 삼성역섬유센터R
# 주소      : 서울특별시 강남구 대치동 944-31 한국섬유산업연합회
# 매장 이름 : 압구정R
# 주소      : 서울특별시 강남구 신사동 621-1
# 매장 이름 : 수서역R
# 주소      : 서울특별시 강남구 수서동 715 수서빌딩
# 매장 이름 : 양재강남빌딩R
# 주소      : 서울특별시 강남구 도곡동 956 LG전자 강남R&D센터
# 매장 이름 : 선릉동신빌딩R
# 주소      : 서울특별시 강남구 삼성동 141-28 동신빌딩
# 매장 이름 : 봉은사로선정릉
# 주소      : 서울특별시 강남구 삼성동 114-9 올림푸스타워
# 매장 이름 : 강남오거리
# 주소      : 서울특별시 강남구 역삼동 813-17 1,2,3층
# 매장 이름 : 스타필드코엑스몰R
# 주소      : 서울특별시 강남구 삼성동 159 코엑스  A106호
# 매장 이름 : 강남구청정문
# 주소      : 서울특별시 강남구 청담동 44-12 대륭빌딩
# 매장 이름 : 도곡공원
# 주소      : 서울특별시 강남구 역삼동 788-10
# ...

# %%
total = pd.DataFrame()
for star in rt['list']:
    total = total.append(pd.DataFrame({'주소' : [star['addr']]}))

# %%
total['주소'].apply(lambda x: x.split()[1]).value_counts()
# Out:
# 강남구     80
# 중구      53
# 서초구     46
# 종로구     38
# 영등포구    34
# 송파구     32
# 마포구     32
# 용산구     19
# 서대문구    19
# 광진구     16
# 강서구     16
# 강동구     15
# 양천구     15
# 성북구     13
# 노원구     12
# 동작구     11
# 관악구     11
# 성동구     11
# 금천구     11
# 구로구     10
# 동대문구     8
# 은평구      8
# 중랑구      7
# 강북구      5
# 도봉구      2
# Name: 주소, dtype: int64

# %%
r2 = requests.get("https://www.starbucks.co.kr/store/store_map.do?disp=locale")

# %%
from bs4 import BeautifulSoup

# %%
bs = BeautifulSoup(r2.text)

# %%
result = bs.findAll("ul", class_="sido_arae_box")

# %%
result
# Out:
# [<ul class="sido_arae_box">
#  </ul>]

# %%
import os

# %%
for roots, dirs, files in os.walk("C:\Windows\System32"):
    for file in files:
        print (file)
# Out:
# @AdvancedKeySettingsNotification.png
# @AppHelpToast.png
# @AudioToastIcon.png
# @BackgroundAccessToastIcon.png
# @bitlockertoastimage.png
# @edptoastimage.png
# @EnrollmentToastIcon.png
# @language_notification_icon.png
# @optionalfeatures.png
# @VpnToastIcon.png
# @windows-hello-V4.1.gif
# @WindowsHelloFaceToastIcon.png
# @WindowsUpdateToastIcon.contrast-black.png
# @WindowsUpdateToastIcon.contrast-white.png
# @WindowsUpdateToastIcon.png
# @WirelessDisplayToast.png
# @WwanNotificationIcon.png
# @WwanSimLockIcon.png
# aadauthhelper.dll
# aadcloudap.dll
# aadjcsp.dll
# aadtb.dll
# aadWamExtension.dll
# AarSvc.dll
# AboutSettingsHandlers.dll
# AboveLockAppHost.dll
# accessibilitycpl.dll
# accountaccessor.dll
# AccountsRt.dll
# AcGenral.dll
# AcLayers.dll
# acledit.dll
# aclui.dll
# acmigration.dll
# ACPBackgroundManagerPolicy.dll
# acppage.dll
# acproxy.dll
# AcSpecfc.dll
# ActionCenter.dll
# ActionCenterCPL.dll
# ActionMgr.dll
# ActionQueue.dll
# ActivationClient.dll
# ...

# %%
# 기본 폴더 : C:\Users\Playdata
# 상대 경로
"./Music/"
# 상대 경로 (C:\Users\Music)
"../Music/"
# 절대 경로 
"C:/Users/Playdata/Music"
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 2003-362A
#
#  C:\Users\Playdata 디렉터리
#
# 2020-08-24  오후 02:14    <DIR>          .
# 2020-08-24  오후 02:14    <DIR>          ..
# 2020-08-24  오후 12:02    <DIR>          .ipynb_checkpoints
# 2020-08-21  오전 11:24    <DIR>          .ipython
# 2020-08-21  오후 01:59    <DIR>          .jupyter
# 2020-08-24  오전 11:04    <DIR>          .matplotlib
# 2020-08-21  오후 03:00    <DIR>          .vscode
# 2020-08-24  오후 02:14           853,888 20200824_starbuck.ipynb
# 2020-08-21  오후 02:17    <DIR>          3D Objects
# 2020-08-21  오전 10:01    <DIR>          Anaconda3
# 2020-08-21  오후 02:17    <DIR>          Contacts
# 2020-08-21  오후 02:17    <DIR>          Desktop
# 2020-08-21  오후 02:17    <DIR>          Documents
# 2020-08-24  오후 12:47    <DIR>          Downloads
# 2020-08-21  오후 02:17    <DIR>          Favorites
# 2020-08-21  오후 02:17    <DIR>          Links
# 2020-08-21  오후 02:17    <DIR>          Music
# 2020-08-21  오전 09:48    <DIR>          OneDrive
# ...

# %%
import os

# %%
# 기본 폴더 확인
os.getcwd()
# Out:
# 'C:\\Users\\Playdata'

# %%
# 기본 폴더 설정
os.chdir("./Play")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Playdata\\Play'

# %%
import shutil

# %%
shutil.move("./tmp.txt", "../tmp.txt")
# Out:
# '../tmp.txt'

# %% [markdown]
# mp3.find("서태지") > 0:
#     shutil.move(원본으로 들어온 파일, "./서태지 모음집")

# %% [markdown]
# ### 파일을 압축을 해제하고 해당 폴더에서 성별을 기준으로 파일을 각각 저장
# ### 파일 안에 있는 금액을 남성, 여성으로 총 합계 구하기

# %% [markdown]
# !pip install pyautogui

# %%
import pyautogui

# %%
pyautogui.position()
# Out:
# Point(x=2785, y=534)

# %%
import time

# %%
while(True):
    pyautogui.moveRel(100, 200)
    time.sleep(5)
    pyautogui.moveRel(-100, -200)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-31744433ac44> in <module>
#       2     pyautogui.moveRel(100, 200)
#       3     time.sleep(5)
# ----> 4     pyautogui.moveRel(-100, -200)
#
# ~\Anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     587         failSafeCheck()
#     588         returnVal = wrappedFunction(*args, **kwargs)
# --> 589         _handlePause(funcArgs.get("_pause"))
#     590         return returnVal
#     591
#
# ~\Anaconda3\lib\site-packages\pyautogui\__init__.py in _handlePause(_pause)
#     631     if _pause:
#     632         assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 633         time.sleep(PAUSE)
#     634
#     635
#
# KeyboardInterrupt:

# %%
pyautogui.screenshot()
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x212C03D1100>
